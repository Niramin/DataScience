# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data={
    "year":[
        2010,2011,2012,
        2010,2011,2012,
        2010,2011,2012
    ],
    "team":[
        'FCBarcelona','FCBarcelona','FCBarcelona',
        'RMadrid',"RMadrid","RMadrid",
        "ValenciaCF","ValenciaCF","ValenciaCF"
    ],
    'wins': [30, 28, 32, 29, 32, 26, 21, 17, 19],
    'draws':  [6, 7, 4, 5, 4, 7, 8, 10, 8],
    'losses': [2, 3, 2, 4, 2, 5, 9, 11, 11]
}
football=pd.DataFrame(data)
print(football)
# Out:
#    year         team  wins  draws  losses
# 0  2010  FCBarcelona    30      6       2
# 1  2011  FCBarcelona    28      7       3
# 2  2012  FCBarcelona    32      4       2
# 3  2010      RMadrid    29      5       4
# 4  2011      RMadrid    32      4       2
# 5  2012      RMadrid    26      7       5
# 6  2010   ValenciaCF    21      8       9
# 7  2011   ValenciaCF    17     10      11
# 8  2012   ValenciaCF    19      8      11

# %%
edu=pd.read_csv(r"C:\Users\Shashwat Ratna\Desktop\realshh\Learn\DataScience\DataScience\educ_figdp_1_Data.csv",na_values=":",usecols=["TIME","GEO","Value"])
edu
# Out:
#      TIME                            GEO  Value
# 0    2000  European Union (28 countries)    NaN
# 1    2001  European Union (28 countries)    NaN
# 2    2002  European Union (28 countries)   5.00
# 3    2003  European Union (28 countries)   5.03
# 4    2004  European Union (28 countries)   4.95
# ..    ...                            ...    ...
# 379  2007                        Finland   5.90
# 380  2008                        Finland   6.10
# 381  2009                        Finland   6.81
# 382  2010                        Finland   6.85
# 383  2011                        Finland   6.76
#
# [384 rows x 3 columns]

# %%
edu.columns
# Out:
# Index(['TIME', 'GEO', 'Value'], dtype='object')

# %%
edu.index
# Out:
# RangeIndex(start=0, stop=384, step=1)

# %%
edu.describe()
# Out:
#               TIME       Value
# count   384.000000  361.000000
# mean   2005.500000    5.203989
# std       3.456556    1.021694
# min    2000.000000    2.880000
# 25%    2002.750000    4.620000
# 50%    2005.500000    5.060000
# 75%    2008.250000    5.660000
# max    2011.000000    8.810000

# %%
edu['Value']
# Out:
# 0       NaN
# 1       NaN
# 2      5.00
# 3      5.03
# 4      4.95
#        ...
# 379    5.90
# 380    6.10
# 381    6.81
# 382    6.85
# 383    6.76
# Name: Value, Length: 384, dtype: float64

# %%
edu.loc[90:94,["TIME","GEO"]].count()
# Out:
# TIME    5
# GEO     5
# dtype: int64

# %%
edu.max()
#max across rows
# Out:
# TIME      2011
# GEO      Spain
# Value     8.81
# dtype: object

# %%
edu[["TIME","Value"]].max(axis=1)
#max across columns
# Out:
# 0      2000.0
# 1      2001.0
# 2      2002.0
# 3      2003.0
# 4      2004.0
#         ...
# 379    2007.0
# 380    2008.0
# 381    2009.0
# 382    2010.0
# 383    2011.0
# Length: 384, dtype: float64

# %%
edu["Value"].isnull()
# Out:
# 0       True
# 1       True
# 2      False
# 3      False
# 4      False
#        ...
# 379    False
# 380    False
# 381    False
# 382    False
# 383    False
# Name: Value, Length: 384, dtype: bool

# %%
edu[edu["Value"].isnull()]
# Out:
#      TIME                            GEO  Value
# 0    2000  European Union (28 countries)    NaN
# 1    2001  European Union (28 countries)    NaN
# 36   2000       Euro area (18 countries)    NaN
# 37   2001       Euro area (18 countries)    NaN
# 48   2000       Euro area (17 countries)    NaN
# 49   2001       Euro area (17 countries)    NaN
# 60   2000       Euro area (15 countries)    NaN
# 72   2000       Euro area (13 countries)    NaN
# 84   2000                        Belgium    NaN
# 174  2006                         Greece    NaN
# 175  2007                         Greece    NaN
# 176  2008                         Greece    NaN
# 177  2009                         Greece    NaN
# 178  2010                         Greece    NaN
# 179  2011                         Greece    NaN
# 252  2000                     Luxembourg    NaN
# 260  2008                     Luxembourg    NaN
# 261  2009                     Luxembourg    NaN
# 262  2010                     Luxembourg    NaN
# ...

# %%
#edu.drop(edu["Value"].isnull(),axis=0) doesnt work, why tho?
edu.dropna(subset=["Value"])
# Out:
#      TIME                            GEO  Value
# 2    2002  European Union (28 countries)   5.00
# 3    2003  European Union (28 countries)   5.03
# 4    2004  European Union (28 countries)   4.95
# 5    2005  European Union (28 countries)   4.92
# 6    2006  European Union (28 countries)   4.91
# ..    ...                            ...    ...
# 379  2007                        Finland   5.90
# 380  2008                        Finland   6.10
# 381  2009                        Finland   6.81
# 382  2010                        Finland   6.85
# 383  2011                        Finland   6.76
#
# [361 rows x 3 columns]

# %%
edu[["GEO","Value"]].groupby("GEO").mean()
# Out:
#                                                      Value
# GEO
# Austria                                           5.618333
# Belgium                                           6.189091
# Bulgaria                                          4.093333
# Cyprus                                            7.023333
# Czech Republic                                    4.168333
# Denmark                                           8.331667
# Estonia                                           5.270833
# Euro area (13 countries)                          5.019091
# Euro area (15 countries)                          5.025455
# Euro area (17 countries)                          4.943000
# Euro area (18 countries)                          4.944000
# European Union (25 countries)                     5.091667
# European Union (27 countries)                     5.060833
# European Union (28 countries)                     5.081000
# Finland                                           6.326667
# ...

# %%
pd.pivot_table(edu,values=["Value"],index=["GEO"],columns=["TIME"],aggfunc=np.mean)
# Out:
#                                                  Value                    \
# TIME                                              2000  2001  2002  2003
# GEO
# Austria                                           5.66  5.74  5.68  5.53
# Belgium                                            NaN  5.99  6.09  6.02
# Bulgaria                                          3.88  3.70  3.94  4.09
# Cyprus                                            5.42  5.98  6.60  7.37
# Czech Republic                                    3.83  3.93  4.15  4.32
# Denmark                                           8.28  8.44  8.44  8.33
# Estonia                                           5.57  5.24  5.47  5.29
# Euro area (13 countries)                           NaN  4.97  5.00  5.04
# Euro area (15 countries)                           NaN  4.98  5.01  5.04
# Euro area (17 countries)                           NaN   NaN  4.86  4.89
# Euro area (18 countries)                           NaN   NaN  4.87  4.89
# ...

# %%
t=pd.pivot_table(edu[edu["TIME"]>2005],values=["Value"],index=["GEO"],columns=["TIME"])
t
# Out:
#                                                  Value                    \
# TIME                                              2006  2007  2008  2009
# GEO
# Austria                                           5.40  5.33  5.47  5.98
# Belgium                                           5.98  6.00  6.43  6.57
# Bulgaria                                          4.04  3.88  4.44  4.58
# Cyprus                                            7.02  6.95  7.45  7.98
# Czech Republic                                    4.42  4.05  3.92  4.36
# Denmark                                           7.97  7.81  7.68  8.74
# Estonia                                           4.70  4.72  5.61  6.03
# Euro area (13 countries)                          4.87  4.80  4.94  5.32
# Euro area (15 countries)                          4.87  4.81  4.95  5.32
# Euro area (17 countries)                          4.69  4.79  4.94  5.31
# Euro area (18 countries)                          4.69  4.79  4.94  5.31
# ...

# %%
t.drop(
    [
        'Euro area (13 countries)',
        'Euro area (15 countries)',
        'Euro area (17 countries)',
        'Euro area (18 countries)',
        'European Union (25 countries)',
        'European Union (27 countries)',
        'European Union (28 countries)'

    ],inplace=True
)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# C:\Temp/ipykernel_8604/2998567097.py in <module>
# ----> 1 t.drop(
#       2     [
#       3         'Euro area (13 countries)',
#       4         'Euro area (15 countries)',
#       5         'Euro area (17 countries)',
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\AppData\Local\Programs\Python\Python38-32\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
# ...

# %%
t.rename(index={'Germany (until 1990 former territory of the FRG)	':'Germany'},inplace=True)

# %%
t=t.dropna()

# %%
t.rank(ascending=False,method='first').head()
# Out:
#                Value
# TIME            2006  2007  2008  2009  2010  2011
# GEO
# Austria         10.0   7.0  11.0   7.0   8.0   8.0
# Belgium          5.0   4.0   3.0   4.0   5.0   5.0
# Bulgaria        21.0  21.0  20.0  20.0  22.0  22.0
# Cyprus           2.0   2.0   2.0   2.0   2.0   3.0
# Czech Republic  19.0  20.0  21.0  21.0  20.0  19.0

# %%
t
# Out:
#                                                  Value                    \
# TIME                                              2006  2007  2008  2009
# GEO
# Austria                                           5.40  5.33  5.47  5.98
# Belgium                                           5.98  6.00  6.43  6.57
# Bulgaria                                          4.04  3.88  4.44  4.58
# Cyprus                                            7.02  6.95  7.45  7.98
# Czech Republic                                    4.42  4.05  3.92  4.36
# Denmark                                           7.97  7.81  7.68  8.74
# Estonia                                           4.70  4.72  5.61  6.03
# Finland                                           6.18  5.90  6.10  6.81
# France                                            5.61  5.62  5.62  5.90
# Germany (until 1990 former territory of the FRG)  4.43  4.49  4.57  5.06
# Hungary                                           5.44  5.29  5.10  5.12
# ...

# %%
totalSum=t.sum(axis=1)
totalSum.rank(ascending=False,method='dense').sort_values().head()
# Out:
# GEO
# Denmark    1.0
# Cyprus     2.0
# Finland    3.0
# Malta      4.0
# Belgium    5.0
# dtype: float64

# %%
tts=t.sum(axis=1).sort_values(ascending=False)
# Out:
# GEO
# Denmark                                             49.76
# Cyprus                                              45.19
# Finland                                             38.60
# Malta                                               38.37
# Belgium                                             38.11
# Ireland                                             34.31
# France                                              34.29
# Netherlands                                         34.18
# Austria                                             33.89
# Slovenia                                            33.12
# Estonia                                             31.88
# Portugal                                            31.74
# Latvia                                              31.42
# Hungary                                             30.56
# Lithuania                                           30.51
# Poland                                              30.44
# ...

# %%
tts.plot(kind="bar",style="b",alpha=0.9,title="Total Values for Each Country")
fig=plt.gcf()
fig.set_size_inches(10,5)

# %%
my_colors=['b','r','g','y','m','c']
t.rename(index={"Germany (until 1990 former territory of the FRG)":"Germany"},inplace=True)
ax=t.plot(kind="barh",stacked=True,color=my_colors,figsize=(12,6))
ax.legend(loc="center left",bbox_to_anchor=(1,0.5))
